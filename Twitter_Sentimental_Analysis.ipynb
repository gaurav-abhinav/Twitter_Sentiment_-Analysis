# %% [markdown]
# ## **Step - 1 :** *Importing Necesaary Libraries and Datasets*

# %% [markdown]
# ### **Step - 1.1 :** *Importing Necesaary Packages & Libraries*

# %%
# DataFrame
import pandas as pd

# Matplot
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.ticker import MaxNLocator
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.metrics import f1_score, accuracy_score


# Keras
from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Embedding, Flatten, Conv1D, MaxPooling1D, LSTM
from keras import utils
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import nltk
nltk.download('omw-1.4')

# Word2vec
import gensim
from gensim.test.utils import common_texts
from gensim.models import Word2Vec


# Utility
import string
import re
import numpy as np
import os
from collections import Counter
import logging
import time
import pickle
import itertools
import random
import datetime

# WordCloud
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from collections import Counter, defaultdict

# Warnings
import warnings
warnings.filterwarnings('ignore')

# Set log
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gauravabhinav/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/gauravabhinav/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/gauravabhinav/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/gauravabhinav/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/gauravabhinav/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ### **Step - 1.2 :** *Importing Dataset*

# %%
  # df = pd.read_csv("../input/twitter-sentiment-dataset/Twitter_Data.csv")
df=pd.read_csv("Twitter_Data.csv")
df1 = df

# %%
df.head(5)
# Out:
#                                           clean_text  category
# 0  when modi promised “minimum government maximum...      -1.0
# 1  talk all the nonsense and continue all the dra...       0.0
# 2  what did just say vote for modi  welcome bjp t...       1.0
# 3  asking his supporters prefix chowkidar their n...       1.0
# 4  answer who among these the most powerful world...       1.0

# %%
df = df[df.category != 0.0]

# %% [markdown]
# ## **Step - 2 :** *Data Pre-processing*

# %% [markdown]
# ### **Step - 2.1 :** Variable Declaration

# %%
df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107767 entries, 0 to 162979
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   clean_text  107765 non-null  object
#  1   category    107760 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.5+ MB

# %%
# Varaibles related to dataset
DATASET_COLUMNS = ["clean_text", "category"]
DATASET_ENCODING = "ISO-8859-1"
TRAIN_SIZE = 0.8

# Parameters for WORD2VEC
W2V_SIZE = 300
W2V_WINDOW = 7
W2V_EPOCH = 32
W2V_MIN_COUNT = 10

# Parameters related to KERAS
SEQUENCE_LENGTH = 300
EPOCHS = 8
BATCH_SIZE = 1024

# Variable specific to SENTIMENT
POSITIVE = "POSITIVE"
NEGATIVE = "NEGATIVE"
NEUTRAL = "NEUTRAL"
SENTIMENT_THRESHOLDS = (0.4, 0.7)

# Variables for Exporting purpose
KERAS_MODEL = "model.h5"
WORD2VEC_MODEL = "model.w2v"
TOKENIZER_MODEL = "tokenizer.pkl"
ENCODER_MODEL = "encoder.pkl"

# MISC

plt.style.use('fivethirtyeight')
pd.options.display.max_columns = 250
pd.options.display.max_rows = 250

# %% [markdown]
# ### **Step - 2.2 :** Null Values Identification and Treatment

# %%
# Confirming presence of missing values in each variable
df.isnull().sum()
# Out:
# clean_text    2
# category      7
# dtype: int64

# %%
df.dropna(how='any', inplace=True) # Removed these rows as the count is small and will not affect overall modelling
df.isnull().sum()
# Out:
# clean_text    0
# category      0
# dtype: int64

# %% [markdown]
# ### **Step - 2.3 :** Label Encoding

# %%
decode_map = {-1.0: "NEGATIVE", 1.0: "POSITIVE"}
def decode_sentiment(label):
    return decode_map[int(label)]

# %%
# %%time
df.category = df.category.apply(lambda x: decode_sentiment(x))
# Out:
# CPU times: user 24.4 ms, sys: 2.15 ms, total: 26.6 ms
# Wall time: 25.3 ms

# %%
category_cnt = Counter(df.category)

plt.figure(figsize=(16,8))
plt.bar(category_cnt.keys(), category_cnt.values())
plt.title("Dataset labels distribuition")
# Out:
# Text(0.5, 1.0, 'Dataset labels distribuition')

# %%
# Including Stopwords and exclusing 'not' related stopwords

stop_words = set(stopwords.words("english"))
stop_words.remove('not')
more_stopwords = {'one', 'br', 'Po', 'th', 'sayi', 'fo', 'Unknown'}
stop_words = stop_words.union(more_stopwords)

stemmer = SnowballStemmer("english")

# %%
def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', text)


def remove_emoji(text):
    emoji_pattern = re.compile(
        '['
        u'\U0001F600-\U0001F64F'  # emoticons
        u'\U0001F300-\U0001F5FF'  # symbols & pictographs
        u'\U0001F680-\U0001F6FF'  # transport & map symbols
        u'\U0001F1E0-\U0001F1FF'  # flags (iOS)
        u'\U00002702-\U000027B0'
        u'\U000024C2-\U0001F251'
        ']+',
        flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)


def remove_html(text):
    html = re.compile(r'^[^ ]<.*?>|&([a-z0-9]+|#[0-9]\"\'\“{1,6}|#x[0-9a-f]{1,6});[^A-Za-z0-9]+')
    return re.sub(html, '', text)


def remove_punct(text):
    table = str.maketrans('', '', string.punctuation)
    return text.translate(table)

def remove_quotes(text):
    quotes = re.compile(r'[^A-Za-z0-9\s]+')
    return re.sub(quotes, '', text)


# Applying helper functions

df['mod_text'] = df['clean_text'].apply(lambda x: remove_URL(x))
df['mod_text'] = df['mod_text'].apply(lambda x: remove_emoji(x))
df['mod_text'] = df['mod_text'].apply(lambda x: remove_html(x))
df['mod_text'] = df['mod_text'].apply(lambda x: remove_punct(x))
df['mod_text'] = df['mod_text'].apply(lambda x: remove_quotes(x))
df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...

# %%
# Tokenizing the tweet base texts.

df['tokenized'] = df['mod_text'].apply(word_tokenize)

df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...

# %%
# Lower casing clean text.

df['lower'] = df['tokenized'].apply(
    lambda x: [word.lower() for word in x])

df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                                lower
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...

# %%
# Removing stopwords.

df['stopwords_removed'] = df['lower'].apply(
    lambda x: [word for word in x if word not in stop_words])

df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                                lower  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                    stopwords_removed
# 0  [modi, promised, minimum, government, maximum,...
# 2  [say, vote, modi, welcome, bjp, told, rahul, m...
# 3  [asking, supporters, prefix, chowkidar, names,...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, going, impor...

# %%
# Applying part of speech tags.

df['pos_tags'] = df['stopwords_removed'].apply(nltk.tag.pos_tag)

df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                                lower  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                    stopwords_removed  \
# 0  [modi, promised, minimum, government, maximum,...
# 2  [say, vote, modi, welcome, bjp, told, rahul, m...
# 3  [asking, supporters, prefix, chowkidar, names,...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, going, impor...
#
#                                             pos_tags
# 0  [(modi, NNS), (promised, VBD), (minimum, JJ), ...
# 2  [(say, VB), (vote, NN), (modi, FW), (welcome, ...
# 3  [(asking, VBG), (supporters, NNS), (prefix, VB...
# 4  [(answer, NN), (among, IN), (powerful, JJ), (w...
# 8  [(upcoming, JJ), (election, NN), (india, NN), ...

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN


df['wordnet_pos'] = df['pos_tags'].apply(
    lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])

df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                                lower  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                    stopwords_removed  \
# 0  [modi, promised, minimum, government, maximum,...
# 2  [say, vote, modi, welcome, bjp, told, rahul, m...
# 3  [asking, supporters, prefix, chowkidar, names,...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, going, impor...
#
#                                             pos_tags  \
# 0  [(modi, NNS), (promised, VBD), (minimum, JJ), ...
# 2  [(say, VB), (vote, NN), (modi, FW), (welcome, ...
# 3  [(asking, VBG), (supporters, NNS), (prefix, VB...
# 4  [(answer, NN), (among, IN), (powerful, JJ), (w...
# 8  [(upcoming, JJ), (election, NN), (india, NN), ...
#
#                                          wordnet_pos
# 0  [(modi, n), (promised, v), (minimum, a), (gove...
# 2  [(say, v), (vote, n), (modi, n), (welcome, a),...
# 3  [(asking, v), (supporters, n), (prefix, v), (c...
# 4  [(answer, n), (among, n), (powerful, a), (worl...
# 8  [(upcoming, a), (election, n), (india, n), (sa...

# %%
# Applying word lemmatizer.

wnl = WordNetLemmatizer()

df['lemmatized'] = df['wordnet_pos'].apply(
    lambda x: [wnl.lemmatize(word, tag) for word, tag in x])

df['lemmatized'] = df['lemmatized'].apply(
    lambda x: [word for word in x if word not in stop_words])

df['lemma_str'] = [' '.join(map(str, l)) for l in df['lemmatized']]

df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                                lower  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                    stopwords_removed  \
# 0  [modi, promised, minimum, government, maximum,...
# 2  [say, vote, modi, welcome, bjp, told, rahul, m...
# 3  [asking, supporters, prefix, chowkidar, names,...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, going, impor...
#
#                                             pos_tags  \
# 0  [(modi, NNS), (promised, VBD), (minimum, JJ), ...
# 2  [(say, VB), (vote, NN), (modi, FW), (welcome, ...
# 3  [(asking, VBG), (supporters, NNS), (prefix, VB...
# 4  [(answer, NN), (among, IN), (powerful, JJ), (w...
# 8  [(upcoming, JJ), (election, NN), (india, NN), ...
#
#                                          wordnet_pos  \
# 0  [(modi, n), (promised, v), (minimum, a), (gove...
# 2  [(say, v), (vote, n), (modi, n), (welcome, a),...
# 3  [(asking, v), (supporters, n), (prefix, v), (c...
# 4  [(answer, n), (among, n), (powerful, a), (worl...
# 8  [(upcoming, a), (election, n), (india, n), (sa...
#
#                                           lemmatized  \
# 0  [modi, promise, minimum, government, maximum, ...
# 2  [say, vote, modi, welcome, bjp, tell, rahul, m...
# 3  [ask, supporter, prefix, chowkidar, name, modi...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, go, importan...
#
#                                            lemma_str
# 0  modi promise minimum government maximum govern...
# 2  say vote modi welcome bjp tell rahul main camp...
# 3  ask supporter prefix chowkidar name modi great...
# 4  answer among powerful world leader today trump...
# 8  upcoming election india saga go important pair...

# %%
print("Total Rows =", len(df.clean_text))
# Out:
# Total Rows = 107758

# %%
df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                                lower  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                    stopwords_removed  \
# 0  [modi, promised, minimum, government, maximum,...
# 2  [say, vote, modi, welcome, bjp, told, rahul, m...
# 3  [asking, supporters, prefix, chowkidar, names,...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, going, impor...
#
#                                             pos_tags  \
# 0  [(modi, NNS), (promised, VBD), (minimum, JJ), ...
# 2  [(say, VB), (vote, NN), (modi, FW), (welcome, ...
# 3  [(asking, VBG), (supporters, NNS), (prefix, VB...
# 4  [(answer, NN), (among, IN), (powerful, JJ), (w...
# 8  [(upcoming, JJ), (election, NN), (india, NN), ...
#
#                                          wordnet_pos  \
# 0  [(modi, n), (promised, v), (minimum, a), (gove...
# 2  [(say, v), (vote, n), (modi, n), (welcome, a),...
# 3  [(asking, v), (supporters, n), (prefix, v), (c...
# 4  [(answer, n), (among, n), (powerful, a), (worl...
# 8  [(upcoming, a), (election, n), (india, n), (sa...
#
#                                           lemmatized  \
# 0  [modi, promise, minimum, government, maximum, ...
# 2  [say, vote, modi, welcome, bjp, tell, rahul, m...
# 3  [ask, supporter, prefix, chowkidar, name, modi...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, go, importan...
#
#                                            lemma_str
# 0  modi promise minimum government maximum govern...
# 2  say vote modi welcome bjp tell rahul main camp...
# 3  ask supporter prefix chowkidar name modi great...
# 4  answer among powerful world leader today trump...
# 8  upcoming election india saga go important pair...

# %%
df_mod = df[["lemma_str", "category"]]
df_mod.head()
# Out:
#                                            lemma_str  category
# 0  modi promise minimum government maximum govern...  NEGATIVE
# 2  say vote modi welcome bjp tell rahul main camp...  POSITIVE
# 3  ask supporter prefix chowkidar name modi great...  POSITIVE
# 4  answer among powerful world leader today trump...  POSITIVE
# 8  upcoming election india saga go important pair...  POSITIVE

# %% [markdown]
# ### **Step - 2.4 :** Train-Test Split

# %%
df_train, df_test = train_test_split(df_mod, test_size=1-TRAIN_SIZE, random_state=42)
print("TRAIN size:", len(df_train))
print("TEST size:", len(df_test))
# Out:
# TRAIN size: 86206
# TEST size: 21552

# %% [markdown]
# ## **Step - 3 :** *Word Cloud Analysis*

# %%
def plot_wordcloud(text, mask, title, title_size, figure_size=(24.0,16.0), image_color=False):
    """ A function for creating wordcloud images """
    words = text
    allwords = []
    for wordlist in words:
        allwords += wordlist
    mostcommon = FreqDist(allwords).most_common(140)
    wordcloud = WordCloud(
                    background_color='white',
                    stopwords = stop_words,
                    max_words = 140,
                    max_font_size = 120,
                    random_state = 42,
                    mask = mask,
    ).generate(str(mostcommon))

    ########

    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = ImageColorGenerator(mask);
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'green',
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout()

# %%
comments_mask = np.array(Image.open('./comment.png'))
plot_wordcloud(df['lemmatized'], comments_mask,
               'Most Common Words',
               title_size=30)

# %% [markdown]
# ## **Step - 4 :** *Word2Vec Analysis*

# %% [markdown]
# ### **Step - 4.1 :** Corpus Creation

# %%
# %%time
documents = [text.split() for text in df_train.lemma_str]
# Out:
# CPU times: user 79.7 ms, sys: 13.5 ms, total: 93.2 ms
# Wall time: 92.3 ms

# %% [markdown]
# ### **Step - 4.2 :** Word2Vec Model Creation

# %%
w2v_model = gensim.models.word2vec.Word2Vec(vector_size=W2V_SIZE,
                                            window=W2V_WINDOW,
                                            min_count=W2V_MIN_COUNT,
                                            workers=8)
# Out:
# 2023-07-10 09:04:55,360 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=0, vector_size=300, alpha=0.025>', 'datetime': '2023-07-10T09:04:55.360576', 'gensim': '4.3.1', 'python': '3.11.4 (main, Jun  7 2023, 00:34:59) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'created'}

# %% [markdown]
# ### **Step - 4.3 :** Vocab Creation

# %%
w2v_model.build_vocab(documents)
# Out:
# 2023-07-10 09:04:57,112 : INFO : collecting all words and their counts
# 2023-07-10 09:04:57,114 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2023-07-10 09:04:57,147 : INFO : PROGRESS: at sentence #10000, processed 164830 words, keeping 18784 word types
# 2023-07-10 09:04:57,171 : INFO : PROGRESS: at sentence #20000, processed 328648 words, keeping 28233 word types
# 2023-07-10 09:04:57,192 : INFO : PROGRESS: at sentence #30000, processed 493344 words, keeping 36201 word types
# 2023-07-10 09:04:57,213 : INFO : PROGRESS: at sentence #40000, processed 657607 words, keeping 43101 word types
# 2023-07-10 09:04:57,232 : INFO : PROGRESS: at sentence #50000, processed 821081 words, keeping 49698 word types
# 2023-07-10 09:04:57,253 : INFO : PROGRESS: at sentence #60000, processed 985061 words, keeping 55768 word types
# 2023-07-10 09:04:57,275 : INFO : PROGRESS: at sentence #70000, processed 1149178 words, keeping 61465 word types
# 2023-07-10 09:04:57,295 : INFO : PROGRESS: at sentence #80000, processed 1315460 words, keeping 67096 word types
# 2023-07-10 09:04:57,308 : INFO : collected 70296 word types from a corpus of 1417640 raw words and 86206 sentences
# 2023-07-10 09:04:57,309 : INFO : Creating a fresh vocabulary
# 2023-07-10 09:04:57,329 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=10 retains 8353 unique words (11.88% of original 70296, drops 61943)', 'datetime': '2023-07-10T09:04:57.329433', 'gensim': '4.3.1', 'python': '3.11.4 (main, Jun  7 2023, 00:34:59) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2023-07-10 09:04:57,330 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=10 leaves 1309789 word corpus (92.39% of original 1417640, drops 107851)', 'datetime': '2023-07-10T09:04:57.330000', 'gensim': '4.3.1', 'python': '3.11.4 (main, Jun  7 2023, 00:34:59) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2023-07-10 09:04:57,345 : INFO : deleting the raw counts dictionary of 70296 items
# 2023-07-10 09:04:57,346 : INFO : sample=0.001 downsamples 39 most-common words
# 2023-07-10 09:04:57,346 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1159345.6720406478 word corpus (88.5%% of prior 1309789)', 'datetime': '2023-07-10T09:04:57.346949', 'gensim': '4.3.1', 'python': '3.11.4 (main, Jun  7 2023, 00:34:59) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2023-07-10 09:04:57,372 : INFO : estimated required memory for 8353 words and 300 dimensions: 24223700 bytes
# 2023-07-10 09:04:57,373 : INFO : resetting layer weights
# 2023-07-10 09:04:57,382 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-07-10T09:04:57.382439', 'gensim': '4.3.1', 'python': '3.11.4 (main, Jun  7 2023, 00:34:59) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'build_vocab'}

# %%
words = w2v_model.wv.key_to_index.keys()
vocab_size = len(words)
print("Vocab size", vocab_size)
# Out:
# Vocab size 8353

# %% [markdown]
# ### **Step - 4.4 :** Training Word2Vec Model

# %%
# %%time
w2v_model.train(documents, total_examples=len(documents), epochs=W2V_EPOCH)
# Out:
# 2023-07-10 09:05:03,295 : INFO : Word2Vec lifecycle event {'msg': 'training model with 8 workers on 8353 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=7 shrink_windows=True', 'datetime': '2023-07-10T09:05:03.295174', 'gensim': '4.3.1', 'python': '3.11.4 (main, Jun  7 2023, 00:34:59) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'train'}
# 2023-07-10 09:05:03,864 : INFO : EPOCH 0: training on 1417640 raw words (1159335 effective words) took 0.6s, 2084654 effective words/s
# 2023-07-10 09:05:04,408 : INFO : EPOCH 1: training on 1417640 raw words (1159213 effective words) took 0.5s, 2151207 effective words/s
# 2023-07-10 09:05:04,956 : INFO : EPOCH 2: training on 1417640 raw words (1159462 effective words) took 0.5s, 2134499 effective words/s
# 2023-07-10 09:05:05,506 : INFO : EPOCH 3: training on 1417640 raw words (1159238 effective words) took 0.5s, 2126073 effective words/s
# 2023-07-10 09:05:06,044 : INFO : EPOCH 4: training on 1417640 raw words (1159266 effective words) took 0.5s, 2175468 effective words/s
# 2023-07-10 09:05:06,590 : INFO : EPOCH 5: training on 1417640 raw words (1159183 effective words) took 0.5s, 2141237 effective words/s
# 2023-07-10 09:05:07,141 : INFO : EPOCH 6: training on 1417640 raw words (1159000 effective words) took 0.5s, 2123484 effective words/s
# 2023-07-10 09:05:07,692 : INFO : EPOCH 7: training on 1417640 raw words (1158997 effective words) took 0.5s, 2120061 effective words/s
# 2023-07-10 09:05:08,239 : INFO : EPOCH 8: training on 1417640 raw words (1159225 effective words) took 0.5s, 2138865 effective words/s
# 2023-07-10 09:05:08,788 : INFO : EPOCH 9: training on 1417640 raw words (1159184 effective words) took 0.5s, 2132019 effective words/s
# 2023-07-10 09:05:09,336 : INFO : EPOCH 10: training on 1417640 raw words (1159601 effective words) took 0.5s, 2134302 effective words/s
# 2023-07-10 09:05:09,880 : INFO : EPOCH 11: training on 1417640 raw words (1159647 effective words) took 0.5s, 2152088 effective words/s
# 2023-07-10 09:05:10,428 : INFO : EPOCH 12: training on 1417640 raw words (1159465 effective words) took 0.5s, 2135402 effective words/s
# 2023-07-10 09:05:10,968 : INFO : EPOCH 13: training on 1417640 raw words (1159623 effective words) took 0.5s, 2166377 effective words/s
# 2023-07-10 09:05:11,510 : INFO : EPOCH 14: training on 1417640 raw words (1159259 effective words) took 0.5s, 2159197 effective words/s
# 2023-07-10 09:05:12,051 : INFO : EPOCH 15: training on 1417640 raw words (1159605 effective words) took 0.5s, 2162746 effective words/s
# 2023-07-10 09:05:12,594 : INFO : EPOCH 16: training on 1417640 raw words (1159067 effective words) took 0.5s, 2156302 effective words/s
# 2023-07-10 09:05:13,133 : INFO : EPOCH 17: training on 1417640 raw words (1159557 effective words) took 0.5s, 2168698 effective words/s
# 2023-07-10 09:05:13,670 : INFO : EPOCH 18: training on 1417640 raw words (1159168 effective words) took 0.5s, 2180612 effective words/s
# 2023-07-10 09:05:14,207 : INFO : EPOCH 19: training on 1417640 raw words (1159415 effective words) took 0.5s, 2179494 effective words/s
# 2023-07-10 09:05:14,744 : INFO : EPOCH 20: training on 1417640 raw words (1158914 effective words) took 0.5s, 2175339 effective words/s
# 2023-07-10 09:05:15,281 : INFO : EPOCH 21: training on 1417640 raw words (1159487 effective words) took 0.5s, 2180503 effective words/s
# 2023-07-10 09:05:15,820 : INFO : EPOCH 22: training on 1417640 raw words (1159572 effective words) took 0.5s, 2169615 effective words/s
# 2023-07-10 09:05:16,361 : INFO : EPOCH 23: training on 1417640 raw words (1159511 effective words) took 0.5s, 2163994 effective words/s
# 2023-07-10 09:05:16,900 : INFO : EPOCH 24: training on 1417640 raw words (1159277 effective words) took 0.5s, 2172431 effective words/s
# 2023-07-10 09:05:17,445 : INFO : EPOCH 25: training on 1417640 raw words (1159302 effective words) took 0.5s, 2142682 effective words/s
# 2023-07-10 09:05:17,989 : INFO : EPOCH 26: training on 1417640 raw words (1159243 effective words) took 0.5s, 2154039 effective words/s
# 2023-07-10 09:05:18,531 : INFO : EPOCH 27: training on 1417640 raw words (1159057 effective words) took 0.5s, 2156309 effective words/s
# 2023-07-10 09:05:19,080 : INFO : EPOCH 28: training on 1417640 raw words (1159434 effective words) took 0.5s, 2129129 effective words/s
# 2023-07-10 09:05:19,636 : INFO : EPOCH 29: training on 1417640 raw words (1159555 effective words) took 0.6s, 2106122 effective words/s
# 2023-07-10 09:05:20,187 : INFO : EPOCH 30: training on 1417640 raw words (1159296 effective words) took 0.5s, 2122185 effective words/s
# 2023-07-10 09:05:20,739 : INFO : EPOCH 31: training on 1417640 raw words (1159469 effective words) took 0.5s, 2119538 effective words/s
# 2023-07-10 09:05:20,740 : INFO : Word2Vec lifecycle event {'msg': 'training on 45364480 raw words (37098627 effective words) took 17.4s, 2126650 effective words/s', 'datetime': '2023-07-10T09:05:20.740076', 'gensim': '4.3.1', 'python': '3.11.4 (main, Jun  7 2023, 00:34:59) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'train'}
# CPU times: user 1min 22s, sys: 538 ms, total: 1min 23s
# Wall time: 17.4 s
# (37098627, 45364480)

# %% [markdown]
# ### **Step - 4.5 :** Word2Vec Model Testing

# %%
w2v_model.wv.most_similar("bjp")
# Out:
# [('trs', 0.4634883403778076),
#  ('party', 0.43364909291267395),
#  ('cadre', 0.42887669801712036),
#  ('coalition', 0.40159308910369873),
#  ('congress', 0.3891967833042145),
#  ('ncp', 0.38242554664611816),
#  ('jds', 0.37805885076522827),
#  ('dmk', 0.3762310743331909),
#  ('ally', 0.373699426651001),
#  ('nota', 0.3673393726348877)]

# %% [markdown]
# ## **Step - 5 :** *Sentiment Analysis using Deep-Learning Model*

# %% [markdown]
# ### **Step - 5.1 :** Token and Vocab Creation

# %%
# %%time
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df_train.lemma_str)

vocab_size = len(tokenizer.word_index) + 1
print("Total words", vocab_size)
# Out:
# Total words 70297
# CPU times: user 774 ms, sys: 8.26 ms, total: 782 ms
# Wall time: 781 ms

# %%
# %%time
x_train = pad_sequences(tokenizer.texts_to_sequences(df_train.lemma_str), maxlen=SEQUENCE_LENGTH)
x_test = pad_sequences(tokenizer.texts_to_sequences(df_test.lemma_str), maxlen=SEQUENCE_LENGTH)
# Out:
# CPU times: user 1.11 s, sys: 231 ms, total: 1.34 s
# Wall time: 1.44 s

# %% [markdown]
# ### **Step - 5.2 :** Label Encoding

# %%
labels = df_train.category.unique().tolist()
labels.append(NEUTRAL)
labels
# Out:
# ['POSITIVE', 'NEGATIVE', 'NEUTRAL']

# %%
encoder = LabelEncoder()
encoder.fit(df_train.category.tolist())

y_train = encoder.transform(df_train.category.tolist())
y_test = encoder.transform(df_test.category.tolist())

y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

print("y_train",y_train.shape)
print("y_test",y_test.shape)
# Out:
# y_train (86206, 1)
# y_test (21552, 1)

# %%
print("x_train", x_train.shape)
print("y_train", y_train.shape)
print()
print("x_test", x_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (86206, 300)
# y_train (86206, 1)
#
# x_test (21552, 300)
# y_test (21552, 1)

# %%
y_train[:10]
# Out:
# array([[1],
#        [0],
#        [0],
#        [1],
#        [1],
#        [1],
#        [0],
#        [1],
#        [0],
#        [1]])

# %% [markdown]
# ### **Step - 5.3 :** Embedding Layer Creation

# %%
embedding_matrix = np.zeros((vocab_size, W2V_SIZE))
for word, i in tokenizer.word_index.items():
  if word in w2v_model.wv:
    embedding_matrix[i] = w2v_model.wv[word]
print(embedding_matrix.shape)
# Out:
# (70297, 300)

# %%
embedding_layer = Embedding(vocab_size, W2V_SIZE, weights=[embedding_matrix], input_length=SEQUENCE_LENGTH, trainable=False)

# %% [markdown]
# ### **Step - 5.4 :** Model Creation - LSTM

# %%
model = Sequential()
model.add(embedding_layer)
model.add(Dropout(0.5))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 300)          21089100
#
#  dropout (Dropout)           (None, 300, 300)          0
#
#  lstm (LSTM)                 (None, 100)               160400
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 21249601 (81.06 MB)
# Trainable params: 160501 (626.96 KB)
# Non-trainable params: 21089100 (80.45 MB)
# _________________________________________________________________

# %% [markdown]
# ### **Step - 5.5 :** Compiling Model

# %%
model.compile(loss='binary_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

# %% [markdown]
# ### **Step - 5.6 :** Callback Creation

# %%
callbacks = [ ReduceLROnPlateau(monitor='val_loss', patience=5, cooldown=0),
              EarlyStopping(monitor='val_acc', min_delta=1e-4, patience=5)]

# %% [markdown]
# ### **Step - 5.7 :** Model Training

# %%
# %%time
history = model.fit(x_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=20,
                    validation_split=0.1,
                    verbose=1,
                    callbacks=callbacks)
# Out:
# Epoch 1/20
# 76/76 [==============================] - ETA: 0s - loss: 0.5893 - accuracy: 0.6775WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 09:11:11,241 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 240s 3s/step - loss: 0.5893 - accuracy: 0.6775 - val_loss: 0.4952 - val_accuracy: 0.7557 - lr: 0.0010
# Epoch 2/20
# 76/76 [==============================] - ETA: 0s - loss: 0.5280 - accuracy: 0.7244WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 09:15:13,298 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 242s 3s/step - loss: 0.5280 - accuracy: 0.7244 - val_loss: 0.4460 - val_accuracy: 0.7948 - lr: 0.0010
# Epoch 3/20
# 76/76 [==============================] - ETA: 0s - loss: 0.4866 - accuracy: 0.7568WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 09:19:59,064 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 286s 4s/step - loss: 0.4866 - accuracy: 0.7568 - val_loss: 0.4061 - val_accuracy: 0.8199 - lr: 0.0010
# Epoch 4/20
# 76/76 [==============================] - ETA: 0s - loss: 0.4543 - accuracy: 0.7806WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 09:25:00,484 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 301s 4s/step - loss: 0.4543 - accuracy: 0.7806 - val_loss: 0.3954 - val_accuracy: 0.8281 - lr: 0.0010
# Epoch 5/20
# 76/76 [==============================] - ETA: 0s - loss: 0.4281 - accuracy: 0.7979WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 09:30:20,782 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 320s 4s/step - loss: 0.4281 - accuracy: 0.7979 - val_loss: 0.3856 - val_accuracy: 0.8398 - lr: 0.0010
# Epoch 6/20
# 76/76 [==============================] - ETA: 0s - loss: 0.4140 - accuracy: 0.8072WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 09:35:43,414 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 323s 4s/step - loss: 0.4140 - accuracy: 0.8072 - val_loss: 0.3756 - val_accuracy: 0.8362 - lr: 0.0010
# Epoch 7/20
# 76/76 [==============================] - ETA: 0s - loss: 0.4020 - accuracy: 0.8150WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 09:40:58,174 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 315s 4s/step - loss: 0.4020 - accuracy: 0.8150 - val_loss: 0.3526 - val_accuracy: 0.8497 - lr: 0.0010
# Epoch 8/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3886 - accuracy: 0.8222WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 09:46:15,004 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 317s 4s/step - loss: 0.3886 - accuracy: 0.8222 - val_loss: 0.3507 - val_accuracy: 0.8564 - lr: 0.0010
# Epoch 9/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3805 - accuracy: 0.8266WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 09:51:10,284 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 295s 4s/step - loss: 0.3805 - accuracy: 0.8266 - val_loss: 0.3423 - val_accuracy: 0.8556 - lr: 0.0010
# Epoch 10/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3750 - accuracy: 0.8290WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 09:56:02,824 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 293s 4s/step - loss: 0.3750 - accuracy: 0.8290 - val_loss: 0.3377 - val_accuracy: 0.8552 - lr: 0.0010
# Epoch 11/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3675 - accuracy: 0.8342WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 10:00:55,123 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 292s 4s/step - loss: 0.3675 - accuracy: 0.8342 - val_loss: 0.3272 - val_accuracy: 0.8623 - lr: 0.0010
# Epoch 12/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3617 - accuracy: 0.8360WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 10:06:39,133 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 344s 5s/step - loss: 0.3617 - accuracy: 0.8360 - val_loss: 0.3300 - val_accuracy: 0.8649 - lr: 0.0010
# Epoch 13/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3563 - accuracy: 0.8394WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 10:11:12,763 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 274s 4s/step - loss: 0.3563 - accuracy: 0.8394 - val_loss: 0.3148 - val_accuracy: 0.8679 - lr: 0.0010
# Epoch 14/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3502 - accuracy: 0.8440WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 10:15:39,900 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 267s 4s/step - loss: 0.3502 - accuracy: 0.8440 - val_loss: 0.3229 - val_accuracy: 0.8654 - lr: 0.0010
# Epoch 15/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3454 - accuracy: 0.8458WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 10:20:10,339 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 270s 4s/step - loss: 0.3454 - accuracy: 0.8458 - val_loss: 0.3146 - val_accuracy: 0.8692 - lr: 0.0010
# Epoch 16/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3433 - accuracy: 0.8458WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 10:24:39,619 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 269s 4s/step - loss: 0.3433 - accuracy: 0.8458 - val_loss: 0.3076 - val_accuracy: 0.8721 - lr: 0.0010
# Epoch 17/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3409 - accuracy: 0.8487WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 10:28:51,484 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 252s 3s/step - loss: 0.3409 - accuracy: 0.8487 - val_loss: 0.3036 - val_accuracy: 0.8745 - lr: 0.0010
# Epoch 18/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3365 - accuracy: 0.8505WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 10:33:10,150 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 259s 3s/step - loss: 0.3365 - accuracy: 0.8505 - val_loss: 0.3023 - val_accuracy: 0.8726 - lr: 0.0010
# Epoch 19/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3318 - accuracy: 0.8529WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 10:37:42,670 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 273s 4s/step - loss: 0.3318 - accuracy: 0.8529 - val_loss: 0.2976 - val_accuracy: 0.8757 - lr: 0.0010
# Epoch 20/20
# 76/76 [==============================] - ETA: 0s - loss: 0.3295 - accuracy: 0.8540WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2023-07-10 10:41:59,500 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 76/76 [==============================] - 257s 3s/step - loss: 0.3295 - accuracy: 0.8540 - val_loss: 0.2982 - val_accuracy: 0.8752 - lr: 0.0010
# CPU times: user 6h 17min 2s, sys: 2h 19min 9s, total: 8h 36min 12s
# Wall time: 1h 34min 48s

# %% [markdown]
# ### **Step - 5.8 :** Model Evaluation

# %%
# %%time
score = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print()
print("ACCURACY:",score[1])
print("LOSS:",score[0])
# Out:
# 22/22 [==============================] - 17s 767ms/step - loss: 0.2927 - accuracy: 0.8787
#
# ACCURACY: 0.878665566444397
# LOSS: 0.29272881150245667
# CPU times: user 54.2 s, sys: 16.2 s, total: 1min 10s
# Wall time: 17.1 s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
def decode_sentiment(score, include_neutral=True):
    if include_neutral:
        label = NEUTRAL ### Whatever not coming in negative and positive sentiments has been considered as neutral
        if score <= SENTIMENT_THRESHOLDS[0]:
            label = NEGATIVE
        elif score >= SENTIMENT_THRESHOLDS[1]:
            label = POSITIVE

        return label
    else:
        return NEGATIVE if score < 0.5 else POSITIVE

# %%
def predict(clean_text, include_neutral=True):
    start_at = time.time()
    # Tokenize clean_text
    x_test = pad_sequences(tokenizer.texts_to_sequences([clean_text]), maxlen=SEQUENCE_LENGTH)
    # Predict
    score = model.predict([x_test])[0]
    # Decode sentiment
    label = decode_sentiment(score, include_neutral=include_neutral)

    return {"label": label, "score": float(score),
       "elapsed_time": time.time()-start_at}

# %%
predict("I love the music")
# Out:
# 1/1 [==============================] - 0s 195ms/step
# {'label': 'POSITIVE',
#  'score': 0.9984471797943115,
#  'elapsed_time': 0.2338240146636963}

# %%
predict("I have nothing to lose")
# Out:
# 1/1 [==============================] - 0s 39ms/step
# {'label': 'NEUTRAL',
#  'score': 0.5972659587860107,
#  'elapsed_time': 0.061321258544921875}

# %%
# 5. Test and Gradio
# !pip install gradio jinja2
# Out:
# Requirement already satisfied: gradio in ./.venv/lib/python3.11/site-packages (3.35.2)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: aiofiles in ./.venv/lib/python3.11/site-packages (from gradio) (23.1.0)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.11/site-packages (from gradio) (3.8.4)
# Requirement already satisfied: altair>=4.2.0 in ./.venv/lib/python3.11/site-packages (from gradio) (5.0.1)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.11/site-packages (from gradio) (0.98.0)
# Requirement already satisfied: ffmpy in ./.venv/lib/python3.11/site-packages (from gradio) (0.3.0)
# Requirement already satisfied: gradio-client>=0.2.7 in ./.venv/lib/python3.11/site-packages (from gradio) (0.2.7)
# Requirement already satisfied: httpx in ./.venv/lib/python3.11/site-packages (from gradio) (0.24.1)
# Requirement already satisfied: huggingface-hub>=0.14.0 in ./.venv/lib/python3.11/site-packages (from gradio) (0.15.1)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in ./.venv/lib/python3.11/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: markupsafe in ./.venv/lib/python3.11/site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.11/site-packages (from gradio) (3.7.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in ./.venv/lib/python3.11/site-packages (from gradio) (0.3.3)
# Requirement already satisfied: numpy in ./.venv/lib/python3.11/site-packages (from gradio) (1.25.0)
# Requirement already satisfied: orjson in ./.venv/lib/python3.11/site-packages (from gradio) (3.9.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.11/site-packages (from gradio) (2.0.2)
# Requirement already satisfied: pillow in ./.venv/lib/python3.11/site-packages (from gradio) (9.5.0)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.11/site-packages (from gradio) (1.10.9)
# Requirement already satisfied: pydub in ./.venv/lib/python3.11/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: pygments>=2.12.0 in ./.venv/lib/python3.11/site-packages (from gradio) (2.15.1)
# Requirement already satisfied: python-multipart in ./.venv/lib/python3.11/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.11/site-packages (from gradio) (6.0)
# Requirement already satisfied: requests in ./.venv/lib/python3.11/site-packages (from gradio) (2.31.0)
# Requirement already satisfied: semantic-version in ./.venv/lib/python3.11/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: uvicorn>=0.14.0 in ./.venv/lib/python3.11/site-packages (from gradio) (0.22.0)
# Requirement already satisfied: websockets>=10.0 in ./.venv/lib/python3.11/site-packages (from gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in ./.venv/lib/python3.11/site-packages (from altair>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in ./.venv/lib/python3.11/site-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.11/site-packages (from gradio-client>=0.2.7->gradio) (2023.6.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.11/site-packages (from gradio-client>=0.2.7->gradio) (23.1)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.11/site-packages (from gradio-client>=0.2.7->gradio) (4.6.3)
# Requirement already satisfied: filelock in ./.venv/lib/python3.11/site-packages (from huggingface-hub>=0.14.0->gradio) (3.12.2)
# Requirement already satisfied: tqdm>=4.42.1 in ./.venv/lib/python3.11/site-packages (from huggingface-hub>=0.14.0->gradio) (4.65.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in ./.venv/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas->gradio) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.11/site-packages (from pandas->gradio) (2023.3)
# Requirement already satisfied: click>=7.0 in ./.venv/lib/python3.11/site-packages (from uvicorn>=0.14.0->gradio) (8.1.3)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.11/site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.11/site-packages (from aiohttp->gradio) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./.venv/lib/python3.11/site-packages (from aiohttp->gradio) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.11/site-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./.venv/lib/python3.11/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.11/site-packages (from aiohttp->gradio) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.11/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.11/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.venv/lib/python3.11/site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.11/site-packages (from httpx->gradio) (2023.5.7)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in ./.venv/lib/python3.11/site-packages (from httpx->gradio) (0.17.2)
# Requirement already satisfied: idna in ./.venv/lib/python3.11/site-packages (from httpx->gradio) (3.4)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.11/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib->gradio) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib->gradio) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib->gradio) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests->gradio) (1.26.16)
# Requirement already satisfied: anyio<5.0,>=3.0 in ./.venv/lib/python3.11/site-packages (from httpcore<0.18.0,>=0.15.0->httpx->gradio) (3.7.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Requirement already satisfied: uc-micro-py in ./.venv/lib/python3.11/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->gradio) (1.16.0)

# %%
import tensorflow as tf
import gradio as gr

# %%
model.save('toxicity89.h5')

# %%
model = tf.keras.models.load_model('toxicity89.h5')

# %%
input_str = ('hey i freaken hate you!')

# %%
res = predict(input_str)
# Out:
# 1/1 [==============================] - 0s 182ms/step

# %%
res
# Out:
# {'label': 'NEGATIVE',
#  'score': 0.002022506669163704,
#  'elapsed_time': 0.21067595481872559}

# %%
def score_comment(comment):
    results = predict(comment)

    text = predict(comment)['label']

    return text

# %%
res = predict(input_str)
# Out:
# 1/1 [==============================] - 0s 46ms/step

# %%
interface = gr.Interface(fn=score_comment,
                         inputs=gr.inputs.Textbox(lines=2, placeholder='Comment to score'),
                        outputs='text')

# %%
interface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://90d346061745b7246b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://90d346061745b7246b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step

# %% [markdown]
# ### **Step - 5.10 :** Creating Confusion Matrix

# %%
# %%time
y_pred_1d = []
y_test_1d = list(df_test.category)
scores = model.predict(x_test, verbose=1, batch_size=8000)
y_pred_1d = [decode_sentiment(score, include_neutral=False) for score in scores]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:2
#
# NameError: name 'df_test' is not defined

# %%
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90, fontsize=22)
    plt.yticks(tick_marks, classes, fontsize=22)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=25)
    plt.xlabel('Predicted label', fontsize=25)

# %%
# %%time

cnf_matrix = confusion_matrix(y_test_1d, y_pred_1d)
plt.figure(figsize=(12,12))
plot_confusion_matrix(cnf_matrix, classes=df_train.category.unique(), title="Confusion matrix")
plt.show()

# %% [markdown]
# ### **Step - 5.11 :** Classification Report

# %%
print(classification_report(y_test_1d, y_pred_1d))

# %% [markdown]
# ### **Step - 5.12 :** Accuracy Score

# %%
accuracy_score(y_test_1d, y_pred_1d)

# %% [markdown]
# ### **Step - 5.13 :** Saving Model for future use

# %%
model.save(KERAS_MODEL)
w2v_model.save(WORD2VEC_MODEL)
pickle.dump(tokenizer, open(TOKENIZER_MODEL, "wb"), protocol=0)
pickle.dump(encoder, open(ENCODER_MODEL, "wb"), protocol=0)
